# %%
from transformers import pipeline

corrector = pipeline("text2text-generation", model="tiendoan/correctDoancs221",device = 'cuda')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from transformers import pipeline
#       3 corrector = pipeline("text2text-generation", model="tiendoan/correctDoancs221",device = 'cuda')
#
# File d:\anaconda3\lib\site-packages\transformers\__init__.py:30
#      27 from typing import TYPE_CHECKING
#      29 # Check the dependencies satisfy the minimal versions required.
# ---> 30 from . import dependency_versions_check
#      31 from .utils import (
#      32     OptionalDependencyNotAvailable,
#      33     _LazyModule,
#    (...)
#      44     logging,
#      45 )
#      48 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File d:\anaconda3\lib\site-packages\transformers\dependency_versions_check.py:36
#      33 if pkg in deps:
#      34     if pkg == "tokenizers":
# ...

# %%
import re
def extract_phrases(text):
        pattern = r'\w[\w ]*|\s\W+|\W+'

        phrases_all = re.findall(pattern, text)

        index_sent_dict = {}
        phrases_str = []
        for ind, phrase in enumerate(phrases_all):
            if not re.match(r'[!"#$%&''()*+,-./:;<=>?@[\]^_`{|}~]', phrase.strip()):
                phrases_str.append(phrase.strip())
                index_sent_dict[ind] = phrase

        return phrases_str, phrases_all, index_sent_dict

# %%
def predict(text,ngram = 5):
    words = text.split()
    sen = []
    pred = []
    i = 1
    for word in (words):
        if(i % ngram == 0):
            pr = corrector(' '.join(sen),max_length=128)[0]['generated_text']
            pred.append(pr)
            sen = []
        sen.append(word)
        i = i + 1
    pred.append(corrector(' '.join(sen))[0]['generated_text'])
    return ' '.join(pred)

# %%
extract_phrases(text)[1]
# Out:
# ['trào ngaymoi']

# %%
text = 'trào ngaymoi'

extracted_text = extract_phrases(text)[1]
preds = []
for sen in (extracted_text): 
    pred = []
    for i in range(len(sen)):
        if(i%2 == 0):  
            pred.append(predict(sen[i],ngram = 5))
        else: pred.append(sen[i])
    preds.append(''.join(pred))
predict(preds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 8
#       6 for i in range(len(sen)):
#       7     if(i%2 == 0):
# ----> 8         pred.append(predict(sen[i],ngram = 5))
#       9     else: pred.append(sen[i])
#      10 preds.append(''.join(pred))
#
# Cell In[3], line 13, in predict(text, ngram)
#      11     sen.append(word)
#      12     i = i + 1
# ---> 13 pred.append(corrector(' '.join(sen))[0]['generated_text'])
#      14 return ' '.join(pred)
#
# NameError: name 'corrector' is not defined
